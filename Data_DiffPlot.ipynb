# %% [markdown]
# <a href="https://colab.research.google.com/github/gowthaman25/DnCNN-keras/blob/master/Data_DiffPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import sweetviz

data = pd.read_csv(r"/content/vehicles.csv")

print(data.head())
# Out:
#            id  ...      long
# 0  7184791621  ...  -92.2550
# 1  7184773187  ...  -92.4638
# 2  7193375964  ...  -73.1336
# 3  7195108810  ... -106.6650
# 4  7184712241  ...  -92.9648
#
# [5 rows x 25 columns]

# %%
#sweet_report.show_html("sweet_report.html")

# %%
#print(list(df.columns)) 
#modes = df["year"].mode()
#df['year'].fillna(modes)

# %%
# creating a Dataframe object  
df = pd.DataFrame(data, columns = ['price', 'year', 
                                      'model','condition','type','paint_color','fuel']) 
  
df = df[(~df.isnull()).all(axis=1)]

#sweet_report = sweetviz.analyze(df)
#sweet_report.show_html('sweet_report.html')

# %%
#sns.pairplot(iris, hue='species', size=2.5);
#sns.scatterplot(x='year',y='type',hue='condition',data=df)
sns.catplot(x="year",y="type",data=df)
#g = sns.PairGrid(df, vars=['year','type'],
#                 hue='condition', palette='RdBu_r')
#g.map(plt.scatter, alpha=0.8)
#g.add_legend();

# %%
sns.catplot(x="condition",y="price",data=df)

# %%
# !pip install wordcloud

# %%
import wordcloud
from wordcloud import WordCloud,STOPWORDS

text2 = pd.read_csv(r"/content/vehicles.csv", usecols=fields)

text = df['condition'].values 
stopwords = set(STOPWORDS) 
wordcloud = WordCloud(max_font_size=50, max_words=10, background_color="black",stopwords = stopwords).generate(str(text))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
sns.catplot(x="year", y="type", hue="fuel",
            col="condition", aspect=.6,
            kind="point", data=df);
